# %% [markdown]
# <a href="https://colab.research.google.com/github/Michael-Augustine/datacamp01/blob/main/Exploratory_data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_swing = pd.read_csv('/new.csv')
df_swing [['PRODUCT_NAME','METAL','MANUFACTURER']]
# Out:
#                                         PRODUCT_NAME    METAL  \
# 0                                       Cumin Powder     Lead
# 1                                             Marker     Lead
# 2     Neo Carmina Herb-Mint Tablets (Unani Medicine)  Arsenic
# 3                                         Siddha Jal     Lead
# 4            Homeopathic remedy for stomach disorder  Mercury
# ...                                              ...      ...
# 5109                                    Chili Powder     Lead
# 5110                                           Spice     Lead
# 5111                                      Ibuprofeno     Lead
# 5112                       Glazed part of a clay pot     Lead
# 5113          Faiza Whitening Soap (Poonia Brothers)  Mercury
#
#                               MANUFACTURER
# 0                    UNKNOWN OR NOT STATED
# 1                    UNKNOWN OR NOT STATED
# 2     Hamdard Laboratories (Waqf) Pakistan
# 3                    UNKNOWN OR NOT STATED
# 4      Kapsons Homoeo Clinics & Pharmacies
# ...                                    ...
# 5109                 UNKNOWN OR NOT STATED
# 5110                 UNKNOWN OR NOT STATED
# 5111          Laboratorios Portugal S.R.L.
# 5112                 UNKNOWN OR NOT STATED
# 5113                 Poonia Brothers (Pak)
#
# [5114 rows x 3 columns]
